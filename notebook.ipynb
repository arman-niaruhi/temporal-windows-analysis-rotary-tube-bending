# %%
import logging
from src.pipeline.report.visualizer import DataVisulizer
from src.pipeline.preprocessing.loader import DataLoader

# %%
visualizer = DataVisulizer()

# %%
logging.disable(logging.CRITICAL)
visualizer.interactive_plot_jupyter(
        df_names=["df_arc", "df_machine_and_movement"],
        x_axes=["Angle[degree]ORDistance[mm]", "index"],  # or use actual column names
        min_id=2,
        max_id=318
    )
# Out:
# IntSlider(value=2, continuous_update=False, description='Experiment ID:', max=318, min=2)
# Output()
